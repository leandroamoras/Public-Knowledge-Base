# %% [markdown]
# # Projeto Ciência de Dados - Previsão de Vendas
#
# - Nosso desafio é conseguir prever as vendas que vamos ter em determinado período com base nos gastos em anúncios nas 3 grandes redes que a empresa Hashtag investe: TV, Jornal e Rádio

# %% [markdown]
# ### Passo a Passo de um Projeto de Ciência de Dados
#
# - Passo 1: Entendimento do Desafio (Quanto que a empresa vai vender se investir em TV, Jornal e Rádio?)
# - Passo 2: Entendimento da Área/Empresa
# - Passo 3: Extração/Obtenção de Dados
# - Passo 4: Ajuste de Dados (Tratamento/Limpeza)
# - Passo 5: Análise Exploratória
# - Passo 6: Modelagem + Algoritmos (Aqui que entra a Inteligência Artificial, se necessário)
# - Passo 7: Interpretação de Resultados

# %% [markdown]
# #### Carregamento e tratamento de dados

# %%
#importando base de dados

import pandas as pd

tabela = pd.read_csv("advertising.csv")
display(tabela)
# Out:
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 2     17.2   45.9    69.3    12.0
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [200 rows x 4 columns]

# %%
#verificando a existência de valores nulos

display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Radio   200 non-null    float64
#  2   Jornal  200 non-null    float64
#  3   Vendas  200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB
# None

# %% [markdown]
# #### Análise Exploratória
# - Vamos tentar visualizar como as informações de cada item estão distribuídas
# - Vamos ver a correlação entre cada um dos itens

# %%
#importando bibliotecas

import seaborn as sns
import matplotlib.pyplot as plt



sns.pairplot(tabela)
plt.show()

#Quem eu quero prever?


sns.heatmap(tabela.corr(), cmap="Wistia", annot=True)
plt.show()

# %% [markdown]
# #### Com isso, podemos partir para a preparação dos dados para treinarmos o Modelo de Machine Learning
#
# - Separando em dados de treino e dados de teste

# %%
#importando bibliotecas

from sklearn.model_selection import train_test_split

x= tabela.drop("Vendas", axis=1)
y= tabela["Vendas"]

x_treino, x_teste, y_treino, y_teste = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# #### Temos um problema de regressão - Vamos escolher os modelos que vamos usar:
#
# - Regressão Linear
# - RandomForest (Árvore de Decisão)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

#criando 2 modelos de AI, Linear Regression e Random Forest
linear = LinearRegression()
randomforest = RandomForestRegressor()

#treinando modelos
linear.fit(x_treino, y_treino)
randomforest.fit(x_treino, y_treino)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### Teste da AI e Avaliação do Melhor Modelo
#
# - Vamos usar o R² -> diz o % que o nosso modelo consegue explicar o que acontece
# - Também vamos olhar o MSE (Erro Quadrático Médio) -> diz o quanto o nosso modelo "erra" quando tenta fazer uma previsão

# %%
#importando metricas (bibliotecas)
from sklearn import metrics

teste_linear = linear.predict(x_teste)
teste_randomforest = randomforest.predict(x_teste)

#metrica de acertos (r2)
r2_linear = metrics.r2_score(y_teste, teste_linear)
r2_randomforest = metrics.r2_score(y_teste, teste_randomforest)
print(r2_linear, r2_randomforest) "Resultados de acertos (r2)/nLinear Regression:{

#metrica de erros
erro_linear = metrics.mean_squared_error(y_teste, teste_linear)
erro_randomforest = metrics.mean_squared_error(y_teste, teste_randomforest)
print(erro_linear, erro_randomforest)

#Conclusão: O randomforest é o modelo que mais acerta e menos erra
# Out:
# 0.9208229177493391 0.9619846117264785
# 2.3771511353187598 1.1413444499999947

# %% [markdown]
# #### Visualização Gráfica das Previsões

# %%
tabela_comparacao = pd.DataFrame()
tabela_comparacao["Vendas Reais"] = y_teste
tabela_comparacao["Previsão Random"] = teste_randomforest
tabela_comparacao = tabela_comparacao.reset_index(drop=True)

#display(tabela_comparacao)
sns.lineplot(data=tabela_comparacao)
plt.show()

# %% [markdown]
# #### Qual a importância de cada variável para as vendas?

# %%
#Mostrando a importância

print("TV| Rádio| Jornal")
print(randomforest.feature_importances_)
# Out:
# TV| Rádio| Jornal
# [0.85908052 0.12219564 0.01872384]

# %% [markdown]
# #### Será que estamos investindo certo?

# %%
#Mostrando qual mídia tem o maior investimento

print(tabela[["Radio", "Jornal"]].sum())
# Out:
# Radio     4652.8
# Jornal    6110.8
# dtype: float64
